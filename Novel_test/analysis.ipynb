# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import random as rd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import data_loader

# %%
def plot(response, categories, participant_cateogries, colors = ['thistle','lightblue','orange']):
    plt.figure(figsize=(15,4))
    cat= [i[0] for i in categories]
    legend_elements = [Patch(facecolor=colors[i], edgecolor='white',
                         label=cat[i]) for i in range(len(cat))]
    sns.violinplot(participant_categories,responses.flatten(),hue=categories[:,:].flatten(),inner='quartile',palette=colors)
    sns.barplot(participant_categories,responses.flatten(),hue=categories[:,:].flatten(),capsize=0.05,alpha=0)
    plt.legend(handles=legend_elements,bbox_to_anchor=(1.05, 1.0), loc='upper left')
    plt.axhline(y=0.5,color='red',linestyle='--')
    plt.ylabel("'for' proportion")
    plt.show()

# %%
data = data_loader.data('data')

# %%
responses, categories, participant_categories = data.get_NP()
plot(responses, categories, participant_categories)

# %%
responses, categories, participant_categories = data.get_resultative()
plot(responses, categories, participant_categories,colors = ['lightblue','orange'])

# %%
responses, categories, participant_categories = data.get_context()
plot(responses, categories, participant_categories,colors = ['lightblue','orange'])

# %%
responses, categories, participant_categories = data.get_transitivity()
plot(responses, categories, participant_categories )

# %%
responses, categories, participant_categories = data.get_goal()
plot(responses, categories, participant_categories,colors = ['lightblue','orange'])

# %%
colors = ['dimgrey', 'darkgrey', 'gainsboro', 'snow']
plot(responses, categories, participant_categories, colors)
